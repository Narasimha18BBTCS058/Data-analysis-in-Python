# %% [markdown]
# <a href="https://colab.research.google.com/github/Narasimha18BBTCS058/Data-analysis-in-Python/blob/main/DAP%20Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

name = input("What is your name? ")
print("Good Luck ! ", name)

words = ['rainbow', 'computer', 'science', 'programming',
        'python', 'mathematics', 'player', 'condition',
        'reverse', 'water', 'board', 'geeks']

word = random.choice(words)


print("Guess the characters")

guesses = ''
turns = 12


while turns > 0:
    failed = 0
    
    for char in word:
        
        if char in guesses:
            print(char)
            
        else:
            print("_")
            failed += 1
            

    if failed == 0:
        print("You Win")
        print("The word is: ", word)
        break

    guess = input("guess a character:")
    
    guesses += guess
    
    if guess not in word:
        
        turns -= 1

        print("Wrong")

        print("You have", + turns, 'more guesses')
        
        
        if turns == 0:
            print("You Loose")

mc
s
a
# Out:
# What is your name? Prithvi
# Good Luck !  Prithvi
# Guess the characters
# _
# _
# _
# _
# _
# _
# _
# _
# _
# guess a character:i
# _
# _
# _
# _
# i
# _
# i
# _
# _
# guess a character:z
# Wrong
# You have 11 more guesses
# _
# _
# _
# _
# i
# _
# i
# _
# _
# guess a character:bhbdc
# Wrong
# You have 10 more guesses
# c
# _
# _
# d
# i
# _
# i
# _
# _
# guess a character:mkwen
# Wrong
# You have 9 more guesses
# c
# _
# n
# d
# i
# _
# i
# _
# n
# guess a character:vkdnewn
# Wrong
# You have 8 more guesses
# c
# _
# n
# d
# i
# _
# i
# _
# n
# guess a character:njlwj
# Wrong
# You have 7 more guesses
# c
# _
# n
# d
# i
# _
# i
# _
# n
# guess a character:nklewn
# guess a character:eni
# Wrong
# You have 6 more guesses
# c
# _
# n
# d
# i
# _
# i
# _
# n
# Wrong
# You have 5 more guesses
# c
# _
# n
# d
# i
# _
# i
# _
# n
# guess a character:e
# Wrong
# You have 4 more guesses
# c
# _
# n
# d
# i
# _
# i
# _
# n
# guess a character:e
# Wrong
# You have 3 more guesses
# c
# _
# n
# ...
